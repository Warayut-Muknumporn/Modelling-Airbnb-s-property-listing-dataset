# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
data = pd.read_csv('listing.csv')
data.shape
# Out:
# (988, 20)

# %%
data.head(5)
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                                     Hanging cabin
#
#                                          Description  \
# 0  ['About this space', "Escape to one of these t...
# 1  ['About this space', "Come and spend a romanti...
# 2  ['About this space', 'Rustic cabin between the...
# 3  ['About this space', 'The Tree top cabin is si...
# 4  ['About this space', 'Feel refreshed at this u...
#
# ...

# %% [markdown]
# #Data Cleaning
#
# the column numbers were not incredibly large nor were they complex. Therefore, all columns were kept for the cleaning stage.

# %%
# Assess the data types and araay structure
print("Data type : ", type(data))
print("Data dims : ", data.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (988, 20)

# %%
df = pd.DataFrame(data)

# %%
def remove_rows_with_missing_ratings(data):
    # Convert data to a pandas DataFrame
    #df = pd.DataFrame(data)
    
    # Get a list of columns that contain 'rating'
    rating_cols = [col for col in data.columns if 'rating' in col]
    
    # Drop rows with missing values in the rating columns
    data.dropna(subset=rating_cols, inplace=True)
    
    # Return the updated DataFrame
    return data


# Drop NaN values in these columns : 'Cleanliness_rating','Accuracy_rating','Communication_rating','Location_rating','Check-in_rating','Value_rating'

# df.dropna(subset = ['Cleanliness_rating','Accuracy_rating','Communication_rating','Location_rating','Check-in_rating','Value_rating'], inplace= True)

# %%
remove_rows_with_missing_ratings(data)


# Assess the number of rows
# print("Data type : ", type(listingsDF))
# print("Data dims : ", listingsDF.shape) 
# We see the first instance of removing/cleaning of rows that do not contain all the data we need.
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 5    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 982  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
def combine_description_strings(data):
    # Remove rows with missing values in the 'Description' column
    data.dropna(subset=['Description'], inplace=True)
# The r prefix in front of a string literal in Python denotes a raw string. 
# In a raw string, backslashes (\) are treated literally, meaning that they are not used as escape characters. 
# For example, the string '\n' is a two-character string consisting of a backslash and the letter 'n',
#  whereas the raw string r'\n' is a two-character string consisting of a backslash and the letter 'n'.
# In the specific case of rep_chars = r'\*|\]|\[', 
# the raw string is used to define a regular expression pattern that matches three specific characters: the asterisk (*), 
# the right square bracket (]), and the left square bracket ([).
# The | symbol in the pattern means "or", so the pattern matches any string that contains any of these three characters. 
    
    # Replace certain characters with empty strings

    rep_char = r'\*|\]|\['
    data['Description'] = data['Description'].str.replace(rep_char, '')
    
        # Replace newline and single quote characters with spaces
    data['Description'].replace([r'\\n', '\n', r"\'"], [' ', ' ', ''], regex=True, inplace=True)
    
    # Remove the phrase 'About this space' and any trailing commas or spaces
    data['Description']=df['Description'].str.strip('About this space, ')
    
    # Return the updated DataFrame
    return data


# Remove the first 'About this space' segment of the Descriptions column, and removing any apostrophes that may confusion down the line.

# df=df[dfF['Description'].str.contains('About this space')== True]
# df['Description'] = df['Description'].str.replace("'About this space',","")
# df['Description'] = df['Description'].str.replace('"',"")
# df['Description'] = df['Description'].str.replace("' '","")
# df['Description'] = df['Description'].str.replace("'","")

# %%
combine_description_strings(data)
# Out:
# <ipython-input-20-46041345454d>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Description'] = data['Description'].str.replace(rep_char, '')
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 5    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 982  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# ...

# %%
def set_default_feature_values(data):
    columns_list=["guests", "beds", "bathrooms", "bedrooms"]
    data[columns_list] = data[columns_list].fillna(1)
    return data

# Replace all listings with empty guests,beds,bathrooms or bedrooms as they should have a minimum of 1.
# df.loc[listingsDF['guests'].isnull(),['guests']] = 1 
# df.loc[listingsDF['beds'].isnull(),['beds']] = 1  
# df.loc[listingsDF['bathrooms'].isnull(),['bathrooms']] = 1  
# df.loc[listingsDF['bedrooms'].isnull(),['bedrooms']] = 1
# df['bathrooms'].loc[listingsDF['bathrooms'] < 1] = 1

# %%
set_default_feature_values(data)
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 5    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 982  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
def clean_tabular_data(data):
    data=remove_rows_with_missing_ratings(data)
    data=combine_description_strings(data)
    data=set_default_feature_values(data)

    return data

# %%
def load_airbnb(data, label_col) :
    # label the columns for seperate from the string 
    labels = data[label_col]
    features = data.select_dtypes(exclude=[object]).drop(label_col, axis=1)

    return features, labels

# %%
clean_tabular_data(data)
# Out:
# <ipython-input-20-46041345454d>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Description'] = data['Description'].str.replace(rep_char, '')
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 5    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 982  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# ...

# %%
# # Index the rows with alphabetical unique IDs

# # Import string module
# import string

# # Create a list of alphabetical ID list
# alphabet = string.ascii_uppercase
# index_list = []
# id_list= None
# row_nums = len(listingsDF)
# for first in alphabet:
#     for second in alphabet:
#         for third in alphabet:
#             index_list.append(first + second + third)
# matched_list = index_list[:row_nums]
# id_list = matched_list

# print(row_nums)
# #Assign the rows with a unique ID in the order of the newly created id_list
# listingsDF["ID"] = id_list
# # listingsDF.set_index("ID", inplace=True)
# listingsDF.head()

# %%
# Print if there are any empty cells remaining.
data.isnull().sum()  # checks for any remaining empty cells.
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description               0
# Amenities                 0
# Location                  0
# guests                    0
# beds                      0
# bathrooms                 0
# Price_Night               0
# Cleanliness_rating        0
# Accuracy_rating           0
# Communication_rating      0
# Location_rating           0
# Check-in_rating           0
# Value_rating              0
# amenities_count           0
# url                       0
# bedrooms                  0
# Unnamed: 19             829
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 830 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                830 non-null    object
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    int64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
#  14  Check-in_rating       830 non-null    float64
# ...

# %%
# So far, no changes to the data type have been made on any of the cells.
# But in order to make statistical tests smooth further down the line, we must change them to float types, where appropriate.

# Convert objects into float 64 for columns 'guests','bedrooms'
data['guests'] = pd.to_numeric(data['guests'], errors='coerce')
data['bedrooms'] = pd.to_numeric(data['bedrooms'], errors='coerce')

# Convert all int64 types into float for statistical analysis later.
data['guests'] = data['guests'].astype(float)
data['bedrooms'] = data['bedrooms'].astype(float)
data['Price_Night'] = data['Price_Night'].astype(float)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 830 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                829 non-null    float64
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    float64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
# ...

# %%
# Export the data as clean_tabular_data.csv

data.to_csv('tabular_data/Test_clean_tabular_data.csv',index=True)
